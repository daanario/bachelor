# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from numba import njit
from numba import jit
import numba as nb
from IPython.display import clear_output
from matplotlib.ticker import PercentFormatter

# %%
@njit
def demand(p1t, p2t, p3t):
    if (p1t < p2t) and (p1t<p3t):
        return 1 - p1t
    elif (p1t == p2t == p3t):
        return 1/3 * (1 - p1t)
    elif (p1t > p2t) or (p1t > p3t):
        return 0
    elif ((p1t < p2t) and (p1t == p3t)) or ((p1t == p2t) and (p1t < p3t)):
        return 1/2 * (1 - p1t)
    
@njit
def profit(p1t, p2t, p3t):
    return p1t * demand(p1t, p2t, p3t)

# %%
@njit
def set_price(i, t, p_table, Q_table, prices, epsilon, draws):
    if epsilon >= np.random.uniform(0,1):
        # pull price from predefined list of randomized choices
        return draws[t]
    else:
        if i == 0:
            j = 1
            k = 2
        if i == 1:
            j = 2
            k = 0
        if i == 2:
            j = 0
            k = 1
        s_t_idx = np.where(prices == p_table[j, t-1])[0][0] # our state (opponent's price)
        r_t_idx = np.where(prices == p_table[k, t-1])[0][0] # our other state (other opponent's price)
        
        maxedQ_idx = np.argmax(Q_table[r_t_idx, s_t_idx, :])
        return prices[maxedQ_idx]

# %%
#This set_price function is extended with the extra parameter r_next which it needs in order to pull the correct price
@njit
def set_price_ext(i, t, p_table, Q_table, prices, epsilon, r_next, draws):
    
    if epsilon >= np.random.uniform(0,1):
        # pull price from predefined list of randomized choices
        return draws[t]
    else:
        if i == 0:
            j = 1
            k = 2
        if i == 1:
            j = 2
            k = 0
        if i == 2:
            j = 0
            k = 1
        s_t_idx = np.where(prices == p_table[j, t-1])[0][0] # our state (opponent's price)
        r_t_idx = np.where(prices == r_next)[0][0]
        
        maxedQ_idx = np.argmax(Q_table[r_t_idx, s_t_idx, :])
        return prices[maxedQ_idx]

# %%
@njit
def Q(p_it_idx, s_t_idx, r_t_idx, i, t, alpha, delta, p_table, Q_table, prices, s_next, r_next) -> float: # p_table contains p and s (opponent price)
    if i == 0:
        j = 1
        k = 2
    if i == 1:
        j = 2
        k = 0
    if i == 2:
        j = 0
        k = 1

    prev_est = Q_table[r_t_idx, s_t_idx, p_it_idx]
    
    #s_next er s_{t+2} mens r_next er r_{t+1} som er blevet trukket fra set_price og set_price_ext. Disse skal bruges i new_est som estimater for hvilke priser firmaerne sætter i de næste perioder. 
    s_next_index = np.where(prices == s_next)[0][0] 
    r_next_index = np.where(prices == r_next)[0][0]
    #Den maksimale Q-værdi om til tidspunkt t+2 givet priserne som vi forventer virksomhederne sætter i denne periode. 
    maxed_Q = max(Q_table[r_next_index, s_next_index, :])
    
    
    
    new_est = profit(p_table[i, t], p_table[j, t], p_table[k, t]) + (delta * profit(p_table[i, t], s_next, p_table[k, t+1])+ delta**2 * profit(p_table[i, t], s_next, r_next))  + delta**3 * maxed_Q

    
    return (1 - alpha) * prev_est + alpha * new_est

# %%
@njit
def curr_prof(p_table, profits, i, t):
    if i == 0:
        j = 1
        k = 2
    if i == 1:
        j = 2
        k = 0
    if i == 2:
        j = 0
        k = 1
    profits[i, t] = profit(p_table[i,t], p_table[j,t], p_table[k,t])
    return

# %%
@njit
def bertrand_simulation(alpha, delta, prices, draws, T):

    i = 0
    j = 1
    k = 2
    t = 0
    # calculate the decay parameter theta
    theta = -(1/1000000)**(1/T) + 1
    epsilon = (1 - theta)**t

    p = len(prices)
    Q_table1 = np.zeros((p, p, p)) # |P| x |S| x |R| matrix
    Q_table2 = np.zeros((p, p, p)) 
    Q_table3 = np.zeros((p, p, p)) 
    p_table = np.empty((3, T))
    p_table.fill(np.nan)
    profits = np.zeros((3, T))

    avg_profs0 = []
    avg_profs1 = []
    avg_profs2 = []
    
    p_table[i, :3] = np.random.choice(prices) # firm 0 sets price for periods t=0:2
    p_table[j, :3] = np.random.choice(prices) # firm 1 sets price for periods t=0:2
    p_table[k, :3] = np.random.choice(prices) # firm 2 sets price for periods t=0:2
    
    t = 3 # 3 periods have passed, so t = 3
    while t < T:

        if i == 0: # update firm 0
            # learning module
            p_it_idx = np.where(prices == p_table[i, t-3])[0][0] # index of p_it
            s_t_idx =  np.where(prices == p_table[j, t-3])[0][0] # index of s_jt
            r_t_idx =  np.where(prices == p_table[k, t-3])[0][0] # index of r_kt
            r_next = set_price(k, t, p_table, Q_table3, prices, epsilon, draws) # firm i makes a guess about firm k's next price
            s_next = set_price_ext(j, t, p_table, Q_table2, prices, epsilon, r_next, draws) # firm i makes a guess about firm s's next price
            # Q-table is updated according to current states (s_it, r_it) and firm i's guesses about (s_it+1, r_it+1) 
            Q_table1[r_t_idx, s_t_idx,p_it_idx] = Q(p_it_idx, s_t_idx,r_t_idx, i, t-3, alpha, delta, p_table, Q_table1, prices, r_next, s_next)

            # action module
            p_table[i, t] = set_price(i, t, p_table, Q_table1, prices, epsilon, draws)
            p_table[j, t] = p_table[j, t-1]
            p_table[k, t] = p_table[k, t-1]
            

        if i == 1: # update firm 1
            # learning module
            p_it_idx = np.where(prices == p_table[i, t-3])[0][0]
            s_t_idx =  np.where(prices == p_table[j, t-3])[0][0]
            r_t_idx =  np.where(prices == p_table[k, t-3])[0][0]
            
            r_next = set_price(k, t, p_table, Q_table1, prices, epsilon, draws)
            s_next = set_price_ext(j, t, p_table, Q_table3, prices, epsilon, r_next, draws)
            Q_table2[r_t_idx, s_t_idx,p_it_idx] = Q(p_it_idx, s_t_idx,r_t_idx, i, t-3, alpha, delta, p_table, Q_table2, prices, r_next, s_next)

            # action module
            p_table[i, t] = set_price(i, t, p_table, Q_table2, prices, epsilon, draws)
            p_table[j, t] = p_table[j, t-1]
            p_table[k, t] = p_table[k, t-1]


        if i ==2: # update firm 2
            # learning module
            p_it_idx = np.where(prices == p_table[i, t-3])[0][0]
            s_t_idx =  np.where(prices == p_table[j, t-3])[0][0]
            r_t_idx =  np.where(prices == p_table[k, t-3])[0][0]
            r_next = set_price(k, t, p_table, Q_table2, prices, epsilon, draws)
            s_next = set_price_ext(j, t, p_table, Q_table1, prices, epsilon, r_next, draws)
            Q_table3[r_t_idx, s_t_idx, p_it_idx] = Q(p_it_idx, s_t_idx,r_t_idx, i, t-3, alpha, delta, p_table, Q_table3, prices, r_next, s_next)
            
            # action module
            p_table[i, t] = set_price(i, t, p_table, Q_table3, prices, epsilon, draws)
            p_table[j, t] = p_table[j, t-1]
            p_table[k, t] = p_table[k, t-1]

        
        # write profits for firm 0, 1 and 2
        curr_prof(p_table, profits, 0, t)
        curr_prof(p_table, profits, 1, t)
        curr_prof(p_table, profits, 2, t)
        
        if t % 50000 == 0:
            # compute avg. of last 1000 profits for each firm
            avg_prof0 = np.sum(profits[0, (t-1000):t])/1000 
            avg_prof1 = np.sum(profits[1, (t-1000):t])/1000
            avg_prof2 = np.sum(profits[2, (t-1000):t])/1000
            
            avg_profs0.append(avg_prof0)
            avg_profs1.append(avg_prof1)
            avg_profs2.append(avg_prof2)
        
        # calculate new epsilon using decay parameter
        epsilon = (1 - theta)**t
        # Update variables
        tmp = i
        i = j
        j = k
        k = tmp
        t += 1
    return p_table, avg_profs0, avg_profs1, avg_profs2

# %%
@njit
def compute_complicity():
    alpha, delta = 0.3, 0.99  # values from Klein(2021)
    prices = np.linspace(0, 1, 7)
    # alpha = np.linspace(0.1,0.6,20)
    # delta = np.linspace(0.6,0.99,20)
    T = 500000
    N = 100
    uniform_prices_draws = [np.random.choice(prices) for i in range(T)]
    #print("drawn prices:", uniform_prices_draws[:100])
    jointprofitability=[]
    complicity=[]
    #jointprofitability=nb.typed.List.empty_list(nb.f8)
    #complicity=nb.typed.List.empty_list(nb.f8)
    for n in range(0, N):
        # alphachoice=np.random.choice(alpha)
        # deltachoice=np.random.choice(delta)
        p_table, avg_profs0, avg_profs1, avg_profs2 = bertrand_simulation(alpha, delta, prices, uniform_prices_draws, T)

        complicity.append(((avg_profs0[-1]+avg_profs1[-1]+avg_profs2[-1])/3)/0.08333333333333333)
    return complicity

# %%
##### UNCOMMENT FOR COMPLICITY
# set parameters
# optionally use a fixed seed
alpha, delta = 0.3, 0.99  # values from Klein(2021)
prices = np.linspace(0, 1, 7)
# alpha = np.linspace(0.1,0.6,20)
# delta = np.linspace(0.6,0.99,20)
T = 500000
N = 100
uniform_prices_draws = [np.random.choice(prices) for i in range(T)]
#print("drawn prices:", uniform_prices_draws[:100])
jointprofitability=[]
complicity=[]
#jointprofitability=nb.typed.List.empty_list(nb.f8)
#complicity=nb.typed.List.empty_list(nb.f8)
for n in range(0, N):
    print(n)
    # alphachoice=np.random.choice(alpha)
    # deltachoice=np.random.choice(delta)
    p_table, avg_profs0, avg_profs1, avg_profs2 = bertrand_simulation(alpha, delta, prices, uniform_prices_draws, T)

    complicity.append(((avg_profs0[-1]+avg_profs1[-1]+avg_profs2[-1])/3)/0.08333333333333333)
    clear_output()
    # if (((profitabilities0[-1]+profitabilities1[-1]+profitabilities2[-1])/3)/0.08333333333333333)>0.6:
    #     print((((profitabilities0[-1]+profitabilities1[-1]+profitabilities2[-1])/3)/0.08333333333333333))
    #     print(alphachoice)
    #     print(deltachoice)

# %%
plt.hist(complicity, bins=[i/10 for i in range(0,11)],rwidth=0.8, weights=np.ones(len(complicity)) / len(complicity))
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.xlabel('$\Delta$')
plt.ylabel('Frequency')
plt.title('Distribution of complicity ($\Delta$) for 100 runs 3 firms')
plt.show()
#plt.savefig('complicity3players100runs.png')

# %%
# complicity = compute_complicity()
# plt.hist(complicity, bins=[i/10 for i in range(0,11)],rwidth=0.8, weights=np.ones(len(complicity)) / len(complicity))
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
# plt.xlabel('$\Delta$')
# plt.ylabel('Frequency')
# plt.title('Distribution of complicity ($\Delta$) for 100 runs 3 firms')
# plt.show()

# %%
#####UNCOMMENT FOR PROFITABILITY PLOT
alpha, delta = 0.3, 0.95  # values from Klein(2021)
T = 500000
N = 10
prices = np.linspace(0, 1, 7)
uniform_prices_draws = [np.random.choice(prices) for i in range(T)]
for n in range(0, N):
    
    p_table, avg_profs0, avg_profs1, avg_profs2 = bertrand_simulation(alpha, delta, prices, uniform_prices_draws, T)
    
    fig, ax = plt.subplots(2)
    
    ax[0].plot(range(0,T), p_table[0,:], color='blue', label = 'prices firm 0')
    ax[0].plot(range(0,T), p_table[1,:], color='red', label = 'prices firm 1')
    ax[0].plot(range(0,T), p_table[2,:], color='yellow', label = 'prices firm 2')
    ax[0].legend()
    # print("Prices",p_table[0,-1],p_table[1,-1],p_table[2,-1])
    average_profitabilities = np.sum([avg_profs0, avg_profs1, avg_profs2], axis=0)/3
    # print("average profitability:\n",average_avg_profs)
    ax[1].plot(np.linspace(0,T,int(T/50000-1)), average_profitabilities, color="purple", label = "avg. profitability")
    ax[1].legend()
    
    

    plt.legend()
    plt.show()
# Out:
# /tmp/ipykernel_114221/2158719404.py:36: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'draws' of function 'set_price'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../tmp/ipykernel_114221/2470574792.py", line 1:
# <source missing, REPL/exec in use?>
#
#   r_next = set_price(k, t, p_table, Q_table3, prices, epsilon, draws) # firm i makes a guess about firm k's next price
# /tmp/ipykernel_114221/2158719404.py:37: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'draws' of function 'set_price_ext'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../tmp/ipykernel_114221/3073088809.py", line 2:
# <source missing, REPL/exec in use?>
#
#   s_next = set_price_ext(j, t, p_table, Q_table2, prices, epsilon, r_next, draws) # firm i makes a guess about firm s's next price
# /tmp/ipykernel_114221/2158719404.py:42: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'draws' of function 'set_price'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../tmp/ipykernel_114221/2470574792.py", line 1:
# <source missing, REPL/exec in use?>
#
#   p_table[i, t] = set_price(i, t, p_table, Q_table1, prices, epsilon, draws)
# /home/daan/anaconda3/lib/python3.9/site-packages/numba/core/ir_utils.py:2147: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'draws' of function 'bertrand_simulation'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../tmp/ipykernel_114221/2158719404.py", line 1:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/numba/core/serialize.py in _numba_unpickle(address, bytedata, hashed)
#      28
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /tmp/ipykernel_114221/555556507.py in <module>
#       7 for n in range(0, N):
#       8
# ----> 9     p_table, avg_profs0, avg_profs1, avg_profs2 = bertrand_simulation(alpha, delta, prices, uniform_prices_draws, T)
#      10
#      11     fig, ax = plt.subplots(2)
#
# SystemError: CPUDispatcher(<function bertrand_simulation at 0x7f1a6037b820>) returned a result with an error set
